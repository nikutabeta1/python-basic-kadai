# %%
from ast import Num
array = ["水","金","地","火","木","土","天","海","冥"]
i = 0
j = 0

for planet in array:
  print(planet)

while array != Num:
  if i != 0:
    break
  i = i + 1
  for j in range(9):
    print(array[j])
# Out:
# 水
# 金
# 地
# 火
# 木
# 土
# 天
# 海
# 冥
# 水
# 金
# 地
# 火
# 木
# 土
# 天
# 海
# 冥
